# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
csv1 = "characters_stats.csv"
powerstats_df = pd.read_csv(csv1, encoding="ISO-8859-1")
powerstats_df
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
corr_df = powerstats_df[["Intelligence", "Strength", "Speed", "Durability", "Power", "Combat"]]
corr_matrix = corr_df.corr()
corr_matrix
# Out:
#               Intelligence  Strength     Speed  Durability     Power    Combat
# Intelligence      1.000000  0.565508  0.619845    0.683933  0.720550  0.783679
# Strength          0.565508  1.000000  0.640657    0.793649  0.639829  0.575045
# Speed             0.619845  0.640657  1.000000    0.704255  0.683467  0.594568
# Durability        0.683933  0.793649  0.704255    1.000000  0.756840  0.679583
# Power             0.720550  0.639829  0.683467    0.756840  1.000000  0.653452
# Combat            0.783679  0.575045  0.594568    0.679583  0.653452  1.000000

# %%
plt.figure(figsize=(15, 10))
sn.heatmap(corr_matrix, annot=True)
png_filepath = "../static/assets/images/corr_matrix.png"
plt.savefig(png_filepath)
plt.show()
